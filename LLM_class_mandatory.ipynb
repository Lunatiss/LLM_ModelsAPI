# %%
# !pip install -q transformers 
# !pip3 install torch torchvision torchaudio

# %% [markdown]
# # Salesforce Model

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("image-to-text", model="Salesforce/blip-image-captioning-large")

# %%
from PIL import Image
import requests

# %%
url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)
text = "A picture of"

# %%
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>
# 'A picture of'

# %%
pipe(image)
# Out:
# [{'generated_text': 'two cats laying on a couch with remote controls on the back'}]

# %%
url_2 = "https://upload.wikimedia.org/wikipedia/commons/thumb/d/d2/Eiffelturm.JPG/280px-Eiffelturm.JPG"
image = Image.open(requests.get(url_2, stream=True).raw)
text = "A picture of"

# %%
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=280x373>

# %%
pipe(image)
# Out:
# [{'generated_text': 'araffe view of the eiffel tower from the park'}]

# %%
url_3 = "https://www.turismotailandes.com/wp-content/uploads/2019/07/Turismo-de-Tailandia-2-e1563977483206.jpg"
image = Image.open(requests.get(url_3, stream=True).raw)
text = "A picture of"

# %%
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x467>

# %%
pipe(image)
# Out:
# [{'generated_text': 'arafed view of a green field with a house in the middle'}]
